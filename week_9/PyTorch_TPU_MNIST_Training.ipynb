# %% [markdown]
# ## PyTorch/TPU MNIST Demo
#
# This colab example corresponds to the implementation under [test_train_mp_mnist.py](https://github.com/pytorch/xla/blob/master/test/test_train_mp_mnist.py).

# %% [markdown]
# <h3>  &nbsp;&nbsp;Use Colab Cloud TPU&nbsp;&nbsp; <a href="https://cloud.google.com/tpu/"><img valign="middle" src="https://raw.githubusercontent.com/GoogleCloudPlatform/tensorflow-without-a-phd/master/tensorflow-rl-pong/images/tpu-hexagon.png" width="50"></a></h3>
#
# * On the main menu, click Runtime and select **Change runtime type**. Set "TPU" as the hardware accelerator.
# * The cell below makes sure you have access to a TPU on Colab.

# %%
import os
assert os.environ['COLAB_TPU_ADDR'], 'Make sure to select TPU from Edit > Notebook settings > Hardware accelerator'

# %% [markdown]
# ### [RUNME] Install Colab TPU compatible PyTorch/TPU wheels and dependencies

# %%
# !pip install cloud-tpu-client==0.10 torch==2.0.0 torchvision==0.15.1 https://storage.googleapis.com/tpu-pytorch/wheels/colab/torch_xla-2.0-cp310-cp310-linux_x86_64.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-xla==2.0
#   Downloading https://storage.googleapis.com/tpu-pytorch/wheels/colab/torch_xla-2.0-cp310-cp310-linux_x86_64.whl (162.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.9/162.9 MB 4.3 MB/s eta 0:00:00
# Collecting cloud-tpu-client==0.10
#   Downloading cloud_tpu_client-0.10-py3-none-any.whl (7.4 kB)
# Collecting torch==2.0.0
#   Downloading torch-2.0.0-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.1 MB/s eta 0:00:00
# Collecting torchvision==0.15.1
#   Downloading torchvision-0.15.1-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 105.1 MB/s eta 0:00:00
# Collecting google-api-python-client==1.8.0 (from cloud-tpu-client==0.10)
#   Downloading google_api_python_client-1.8.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from cloud-tpu-client==0.10) (4.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (3.1.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.0)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 71.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.0)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 61.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.0)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 102.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.0)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.2 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.0)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.1 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.0)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 5.0 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.0)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 29.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.0)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 7.7 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.0)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 4.7 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.0)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 4.5 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.0)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.1) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.1) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.1) (8.4.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.21.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (0.1.0)
# Collecting google-api-core<2dev,>=1.13.0 (from google-api-python-client==1.8.0->cloud-tpu-client==0.10)
#   Downloading google_api_core-1.34.0-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.2/120.2 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.16.0)
# Collecting uritemplate<4dev,>=3.0.0 (from google-api-python-client==1.8.0->cloud-tpu-client==0.10)
#   Downloading uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.0) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.0) (0.40.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0) (16.0.5)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from torch-xla==2.0) (1.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.0) (2.1.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->cloud-tpu-client==0.10) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->cloud-tpu-client==0.10) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->cloud-tpu-client==0.10) (4.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.0) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (1.59.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.20.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (5.3.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.9.2->google-api-python-client==1.8.0->cloud-tpu-client==0.10) (3.0.9)
# Installing collected packages: uritemplate, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, google-api-core, google-api-python-client, cloud-tpu-client, torch-xla, torch, torchvision
#   Attempting uninstall: uritemplate
#     Found existing installation: uritemplate 4.1.1
#     Uninstalling uritemplate-4.1.1:
#       Successfully uninstalled uritemplate-4.1.1
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.11.0
#     Uninstalling google-api-core-2.11.0:
#       Successfully uninstalled google-api-core-2.11.0
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.84.0
#     Uninstalling google-api-python-client-2.84.0:
#       Successfully uninstalled google-api-python-client-2.84.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.2+cu118
#     Uninstalling torchvision-0.15.2+cu118:
#       Successfully uninstalled torchvision-0.15.2+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# earthengine-api 0.1.350 requires google-api-python-client>=1.12.1, but you have google-api-python-client 1.8.0 which is incompatible.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# Successfully installed cloud-tpu-client-0.10 google-api-core-1.34.0 google-api-python-client-1.8.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.0 torch-xla-2.0.0.dev20230516+colab torchvision-0.15.1 uritemplate-3.0.1

# %% [markdown]
# ### Define Parameters and Helpers, and start Training

# %%
# Result Visualization Helper
import math
from matplotlib import pyplot as plt

M, N = 4, 6
RESULT_IMG_PATH = '/tmp/test_result.png'

def plot_results(images, labels, preds):
  images, labels, preds = images[:M*N], labels[:M*N], preds[:M*N]
  inv_norm = transforms.Normalize((-0.1307/0.3081,), (1/0.3081,))

  num_images = images.shape[0]
  fig, axes = plt.subplots(M, N, figsize=(11, 9))
  fig.suptitle('Correct / Predicted Labels (Red text for incorrect ones)')

  for i, ax in enumerate(fig.axes):
    ax.axis('off')
    if i >= num_images:
      continue
    img, label, prediction = images[i], labels[i], preds[i]
    img = inv_norm(img)
    img = img.squeeze() # [1,Y,X] -> [Y,X]
    label, prediction = label.item(), prediction.item()
    if label == prediction:
      ax.set_title(u'\u2713', color='blue', fontsize=22)
    else:
      ax.set_title(
          'X {}/{}'.format(label, prediction), color='red')
    ax.imshow(img)
  plt.savefig(RESULT_IMG_PATH, transparent=True)

# %%
# Define Parameters
FLAGS = {}
FLAGS['datadir'] = "/tmp/mnist"
FLAGS['batch_size'] = 128
FLAGS['num_workers'] = 4
FLAGS['learning_rate'] = 0.01
FLAGS['momentum'] = 0.5
FLAGS['num_epochs'] = 10
FLAGS['num_cores'] = 8
FLAGS['log_steps'] = 20
FLAGS['metrics_debug'] = False

# %%
import numpy as np
import os
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch_xla
import torch_xla.core.xla_model as xm
import torch_xla.debug.metrics as met
import torch_xla.distributed.parallel_loader as pl
import torch_xla.distributed.xla_multiprocessing as xmp
import torch_xla.utils.utils as xu
from torchvision import datasets, transforms


SERIAL_EXEC = xmp.MpSerialExecutor()

class MNIST(nn.Module):

  def __init__(self):
    super(MNIST, self).__init__()
    self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
    self.bn1 = nn.BatchNorm2d(10)
    self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
    self.bn2 = nn.BatchNorm2d(20)
    self.fc1 = nn.Linear(320, 50)
    self.fc2 = nn.Linear(50, 10)

  def forward(self, x):
    x = F.relu(F.max_pool2d(self.conv1(x), 2))
    x = self.bn1(x)
    x = F.relu(F.max_pool2d(self.conv2(x), 2))
    x = self.bn2(x)
    x = torch.flatten(x, 1)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return F.log_softmax(x, dim=1)

# Only instantiate model weights once in memory.
WRAPPED_MODEL = xmp.MpModelWrapper(MNIST())

def train_mnist():
  torch.manual_seed(1)

  def get_dataset():
    norm = transforms.Normalize((0.1307,), (0.3081,))
    train_dataset = datasets.MNIST(
        FLAGS['datadir'],
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.ToTensor(), norm]))
    test_dataset = datasets.MNIST(
        FLAGS['datadir'],
        train=False,
        download=True,
        transform=transforms.Compose(
            [transforms.ToTensor(), norm]))

    return train_dataset, test_dataset

  # Using the serial executor avoids multiple processes to
  # download the same data.
  train_dataset, test_dataset = SERIAL_EXEC.run(get_dataset)

  train_sampler = torch.utils.data.distributed.DistributedSampler(
    train_dataset,
    num_replicas=xm.xrt_world_size(),
    rank=xm.get_ordinal(),
    shuffle=True)
  train_loader = torch.utils.data.DataLoader(
      train_dataset,
      batch_size=FLAGS['batch_size'],
      sampler=train_sampler,
      num_workers=FLAGS['num_workers'],
      drop_last=True)
  test_loader = torch.utils.data.DataLoader(
      test_dataset,
      batch_size=FLAGS['batch_size'],
      shuffle=False,
      num_workers=FLAGS['num_workers'],
      drop_last=True)

  # Scale learning rate to world size
  lr = FLAGS['learning_rate'] * xm.xrt_world_size()

  # Get loss function, optimizer, and model
  device = xm.xla_device()
  model = WRAPPED_MODEL.to(device)
  optimizer = optim.SGD(model.parameters(), lr=lr, momentum=FLAGS['momentum'])
  loss_fn = nn.NLLLoss()

  def train_loop_fn(loader):
    tracker = xm.RateTracker()
    model.train()
    for x, (data, target) in enumerate(loader):
      optimizer.zero_grad()
      output = model(data)
      loss = loss_fn(output, target)
      loss.backward()
      xm.optimizer_step(optimizer)
      tracker.add(FLAGS['batch_size'])
      if x % FLAGS['log_steps'] == 0:
        print('[xla:{}]({}) Loss={:.5f} Rate={:.2f} GlobalRate={:.2f} Time={}'.format(
            xm.get_ordinal(), x, loss.item(), tracker.rate(),
            tracker.global_rate(), time.asctime()), flush=True)

  def test_loop_fn(loader):
    total_samples = 0
    correct = 0
    model.eval()
    data, pred, target = None, None, None
    for data, target in loader:
      output = model(data)
      pred = output.max(1, keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()
      total_samples += data.size()[0]

    accuracy = 100.0 * correct / total_samples
    print('[xla:{}] Accuracy={:.2f}%'.format(
        xm.get_ordinal(), accuracy), flush=True)
    return accuracy, data, pred, target

  # Train and eval loops
  accuracy = 0.0
  data, pred, target = None, None, None
  for epoch in range(1, FLAGS['num_epochs'] + 1):
    para_loader = pl.ParallelLoader(train_loader, [device])
    train_loop_fn(para_loader.per_device_loader(device))
    xm.master_print("Finished training epoch {}".format(epoch))

    para_loader = pl.ParallelLoader(test_loader, [device])
    accuracy, data, pred, target  = test_loop_fn(para_loader.per_device_loader(device))
    if FLAGS['metrics_debug']:
      xm.master_print(met.metrics_report(), flush=True)

  return accuracy, data, pred, target

# %%
# Start training processes
def _mp_fn(rank, flags):
  global FLAGS
  FLAGS = flags
  torch.set_default_tensor_type('torch.FloatTensor')
  accuracy, data, pred, target = train_mnist()
  if rank == 0:
    # Retrieve tensors that are on TPU core 0 and plot.
    plot_results(data.cpu(), pred.cpu(), target.cpu())

xmp.spawn(_mp_fn, args=(FLAGS,), nprocs=FLAGS['num_cores'],
          start_method='fork')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 91843490.42it/s]
# Extracting /tmp/mnist/MNIST/raw/train-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 111235715.17it/s]
# Extracting /tmp/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 21802523.90it/s]
# Extracting /tmp/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to /tmp/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 19146260.07it/s]
# Extracting /tmp/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to /tmp/mnist/MNIST/raw
#
# [xla:2](0) Loss=2.29280 Rate=228.66 GlobalRate=228.65 Time=Thu Jun 15 16:22:34 2023[xla:0](0) Loss=2.30130 Rate=138.01 GlobalRate=138.01 Time=Thu Jun 15 16:22:34 2023
#
# [xla:7](0) Loss=2.26931 Rate=296.78 GlobalRate=296.77 Time=Thu Jun 15 16:22:34 2023
# [xla:1](0) Loss=2.31269 Rate=456.76 GlobalRate=456.74 Time=Thu Jun 15 16:22:34 2023
# [xla:6](0) Loss=2.32783 Rate=452.21 GlobalRate=452.20 Time=Thu Jun 15 16:22:34 2023
# [xla:4](0) Loss=2.29142 Rate=526.28 GlobalRate=526.26 Time=Thu Jun 15 16:22:35 2023
# [xla:3](0) Loss=2.30902 Rate=527.20 GlobalRate=527.18 Time=Thu Jun 15 16:22:35 2023
# [xla:5](0) Loss=2.28664 Rate=430.89 GlobalRate=430.86 Time=Thu Jun 15 16:22:35 2023
# [xla:3](20) Loss=0.35357 Rate=855.13 GlobalRate=1023.23 Time=Thu Jun 15 16:22:37 2023
# [xla:5](20) Loss=0.38562 Rate=892.15 GlobalRate=1105.71 Time=Thu Jun 15 16:22:37 2023[xla:2](20) Loss=0.38587 Rate=546.46 GlobalRate=682.99 Time=Thu Jun 15 16:22:37 2023[xla:7](20) Loss=0.40944 Rate=574.56 GlobalRate=707.20 Time=Thu Jun 15 16:22:37 2023[xla:6](20) Loss=0.28816 Rate=672.08 GlobalRate=788.23 Time=Thu Jun 15 16:22:37 2023
#
#
#
# [xla:0](20) Loss=0.41817 Rate=510.13 GlobalRate=624.56 Time=Thu Jun 15 16:22:37 2023[xla:4](20) Loss=0.38561 Rate=776.68 GlobalRate=909.28 Time=Thu Jun 15 16:22:37 2023[xla:1](20) Loss=0.32908 Rate=645.57 GlobalRate=746.94 Time=Thu Jun 15 16:22:37 2023
#
#
# [xla:3](40) Loss=0.22885 Rate=2597.00 GlobalRate=1586.38 Time=Thu Jun 15 16:22:38 2023
# [xla:4](40) Loss=0.12835 Rate=2584.19 GlobalRate=1445.02 Time=Thu Jun 15 16:22:38 2023[xla:1](40) Loss=0.18866 Rate=2531.89 GlobalRate=1227.82 Time=Thu Jun 15 16:22:38 2023[xla:5](40) Loss=0.16148 Rate=2611.54 GlobalRate=1686.23 Time=Thu Jun 15 16:22:38 2023[xla:2](40) Loss=0.16745 Rate=2472.24 GlobalRate=1136.62 Time=Thu Jun 15 16:22:38 2023[xla:6](40) Loss=0.24495 Rate=2524.73 GlobalRate=1282.80 Time=Thu Jun 15 16:22:38 2023[xla:0](40) Loss=0.19767 Rate=2472.92 GlobalRate=1053.64 Time=Thu Jun 15 16:22:38 2023[xla:7](40) Loss=0.20532 Rate=2483.23 GlobalRate=1170.77 Time=Thu Jun 15 16:22:38 2023
#
#
#
#
#
#
# Finished training epoch 1
# [xla:7] Accuracy=96.28%[xla:0] Accuracy=96.29%[xla:1] Accuracy=96.30%
#
#
# [xla:4] Accuracy=96.28%
# [xla:3] Accuracy=96.32%
# [xla:2] Accuracy=96.29%
# [xla:5] Accuracy=96.29%
# [xla:6] Accuracy=96.30%
# [xla:1](0) Loss=0.17344 Rate=287.92 GlobalRate=287.91 Time=Thu Jun 15 16:22:43 2023
# [xla:0](0) Loss=0.14407 Rate=250.59 GlobalRate=250.56 Time=Thu Jun 15 16:22:43 2023
# [xla:7](0) Loss=0.20126 Rate=251.67 GlobalRate=251.66 Time=Thu Jun 15 16:22:43 2023
# [xla:2](0) Loss=0.18891 Rate=220.35 GlobalRate=220.34 Time=Thu Jun 15 16:22:43 2023
# [xla:3](0) Loss=0.12272 Rate=209.85 GlobalRate=209.83 Time=Thu Jun 15 16:22:43 2023
# [xla:6](0) Loss=0.21758 Rate=240.83 GlobalRate=240.83 Time=Thu Jun 15 16:22:43 2023
# [xla:4](0) Loss=0.12522 Rate=195.79 GlobalRate=195.79 Time=Thu Jun 15 16:22:43 2023
# [xla:5](0) Loss=0.15870 Rate=222.62 GlobalRate=222.61 Time=Thu Jun 15 16:22:43 2023
# [xla:1](20) Loss=0.07879 Rate=1829.34 GlobalRate=2005.02 Time=Thu Jun 15 16:22:43 2023[xla:5](20) Loss=0.14567 Rate=2230.56 GlobalRate=2080.11 Time=Thu Jun 15 16:22:43 2023[xla:7](20) Loss=0.18789 Rate=1951.91 GlobalRate=2008.47 Time=Thu Jun 15 16:22:43 2023[xla:3](20) Loss=0.14276 Rate=2069.80 GlobalRate=1942.99 Time=Thu Jun 15 16:22:43 2023[xla:6](20) Loss=0.04901 Rate=2118.55 GlobalRate=2082.01 Time=Thu Jun 15 16:22:43 2023[xla:2](20) Loss=0.15660 Rate=2007.80 GlobalRate=1946.36 Time=Thu Jun 15 16:22:43 2023[xla:4](20) Loss=0.13578 Rate=2205.69 GlobalRate=1953.79 Time=Thu Jun 15 16:22:43 2023[xla:0](20) Loss=0.13765 Rate=1838.13 GlobalRate=1927.39 Time=Thu Jun 15 16:22:43 2023
#
#
#
#
#
#
#
# [xla:5](40) Loss=0.07363 Rate=3335.64 GlobalRate=2732.10 Time=Thu Jun 15 16:22:44 2023[xla:2](40) Loss=0.07335 Rate=3246.24 GlobalRate=2611.28 Time=Thu Jun 15 16:22:44 2023[xla:3](40) Loss=0.11434 Rate=3272.19 GlobalRate=2608.55 Time=Thu Jun 15 16:22:44 2023[xla:6](40) Loss=0.10494 Rate=3292.29 GlobalRate=2734.31 Time=Thu Jun 15 16:22:44 2023[xla:0](40) Loss=0.12978 Rate=3181.19 GlobalRate=2594.67 Time=Thu Jun 15 16:22:44 2023[xla:1](40) Loss=0.10333 Rate=3174.53 GlobalRate=2664.74 Time=Thu Jun 15 16:22:44 2023[xla:4](40) Loss=0.05057 Rate=3325.51 GlobalRate=2618.15 Time=Thu Jun 15 16:22:44 2023[xla:7](40) Loss=0.10679 Rate=3224.35 GlobalRate=2668.13 Time=Thu Jun 15 16:22:44 2023
#
#
#
#
#
#
#
# Finished training epoch 2
# [xla:5] Accuracy=97.69%[xla:2] Accuracy=97.68%[xla:1] Accuracy=97.69%
# [xla:3] Accuracy=97.71%
# [xla:0] Accuracy=97.67%[xla:4] Accuracy=97.70%[xla:6] Accuracy=97.70%
#
#
#
#
# [xla:7] Accuracy=97.70%
# [xla:0](0) Loss=0.09009 Rate=247.42 GlobalRate=247.41 Time=Thu Jun 15 16:22:48 2023
# [xla:7](0) Loss=0.13505 Rate=229.08 GlobalRate=229.08 Time=Thu Jun 15 16:22:48 2023
# [xla:3](0) Loss=0.07002 Rate=205.59 GlobalRate=205.58 Time=Thu Jun 15 16:22:48 2023
# [xla:1](0) Loss=0.08998 Rate=198.52 GlobalRate=198.52 Time=Thu Jun 15 16:22:48 2023[xla:2](0) Loss=0.13836 Rate=197.87 GlobalRate=197.87 Time=Thu Jun 15 16:22:48 2023
#
# [xla:6](0) Loss=0.14697 Rate=222.38 GlobalRate=222.38 Time=Thu Jun 15 16:22:48 2023
# [xla:4](0) Loss=0.07595 Rate=190.66 GlobalRate=190.65 Time=Thu Jun 15 16:22:48 2023[xla:5](0) Loss=0.07967 Rate=186.40 GlobalRate=186.40 Time=Thu Jun 15 16:22:48 2023
#
# [xla:7](20) Loss=0.14091 Rate=2136.39 GlobalRate=2051.98 Time=Thu Jun 15 16:22:49 2023[xla:5](20) Loss=0.11068 Rate=2525.75 GlobalRate=2046.68 Time=Thu Jun 15 16:22:49 2023[xla:2](20) Loss=0.10896 Rate=2383.38 GlobalRate=2046.46 Time=Thu Jun 15 16:22:49 2023[xla:6](20) Loss=0.02267 Rate=2452.18 GlobalRate=2193.29 Time=Thu Jun 15 16:22:49 2023[xla:3](20) Loss=0.11425 Rate=2308.47 GlobalRate=2047.89 Time=Thu Jun 15 16:22:49 2023[xla:0](20) Loss=0.09835 Rate=2032.62 GlobalRate=2049.24 Time=Thu Jun 15 16:22:49 2023[xla:1](20) Loss=0.04646 Rate=2382.84 GlobalRate=2049.40 Time=Thu Jun 15 16:22:49 2023[xla:4](20) Loss=0.08521 Rate=2528.31 GlobalRate=2071.21 Time=Thu Jun 15 16:22:49 2023
#
#
#
#
#
#
#
# [xla:2](40) Loss=0.04712 Rate=3414.08 GlobalRate=2708.37 Time=Thu Jun 15 16:22:49 2023[xla:5](40) Loss=0.04249 Rate=3470.84 GlobalRate=2708.52 Time=Thu Jun 15 16:22:49 2023[xla:0](40) Loss=0.11312 Rate=3273.88 GlobalRate=2710.90 Time=Thu Jun 15 16:22:49 2023[xla:1](40) Loss=0.07616 Rate=3414.22 GlobalRate=2711.14 Time=Thu Jun 15 16:22:49 2023[xla:6](40) Loss=0.06493 Rate=3441.49 GlobalRate=2837.05 Time=Thu Jun 15 16:22:49 2023[xla:7](40) Loss=0.07153 Rate=3314.04 GlobalRate=2712.88 Time=Thu Jun 15 16:22:49 2023[xla:3](40) Loss=0.08022 Rate=3379.83 GlobalRate=2708.13 Time=Thu Jun 15 16:22:49 2023
#
#
# [xla:4](40) Loss=0.03050 Rate=3468.63 GlobalRate=2729.26 Time=Thu Jun 15 16:22:49 2023
#
#
#
#
# Finished training epoch 3
# [xla:2] Accuracy=98.16%[xla:4] Accuracy=98.18%[xla:0] Accuracy=98.17%
#
#
# [xla:1] Accuracy=98.17%[xla:6] Accuracy=98.17%
#
# [xla:5] Accuracy=98.19%[xla:7] Accuracy=98.17%[xla:3] Accuracy=98.19%
#
#
# [xla:1](0) Loss=0.06194 Rate=237.38 GlobalRate=237.37 Time=Thu Jun 15 16:22:53 2023
# [xla:2](0) Loss=0.10703 Rate=222.52 GlobalRate=222.52 Time=Thu Jun 15 16:22:53 2023
# [xla:7](0) Loss=0.10647 Rate=207.82 GlobalRate=207.82 Time=Thu Jun 15 16:22:53 2023
# [xla:6](0) Loss=0.10205 Rate=204.07 GlobalRate=204.06 Time=Thu Jun 15 16:22:53 2023
# [xla:0](0) Loss=0.06790 Rate=196.39 GlobalRate=196.39 Time=Thu Jun 15 16:22:53 2023[xla:3](0) Loss=0.04909 Rate=200.64 GlobalRate=200.63 Time=Thu Jun 15 16:22:53 2023
#
# [xla:4](0) Loss=0.06278 Rate=192.46 GlobalRate=192.45 Time=Thu Jun 15 16:22:53 2023
# [xla:5](0) Loss=0.04789 Rate=190.06 GlobalRate=190.05 Time=Thu Jun 15 16:22:53 2023
# [xla:5](20) Loss=0.10019 Rate=2517.60 GlobalRate=2063.58 Time=Thu Jun 15 16:22:54 2023[xla:7](20) Loss=0.11532 Rate=2271.83 GlobalRate=2039.91 Time=Thu Jun 15 16:22:54 2023[xla:0](20) Loss=0.07832 Rate=2369.44 GlobalRate=2032.90 Time=Thu Jun 15 16:22:54 2023[xla:4](20) Loss=0.06823 Rate=2411.39 GlobalRate=2031.62 Time=Thu Jun 15 16:22:54 2023[xla:1](20) Loss=0.03264 Rate=2062.88 GlobalRate=2036.75 Time=Thu Jun 15 16:22:54 2023[xla:2](20) Loss=0.08299 Rate=2141.59 GlobalRate=2030.89 Time=Thu Jun 15 16:22:54 2023[xla:3](20) Loss=0.10489 Rate=2383.53 GlobalRate=2059.99 Time=Thu Jun 15 16:22:54 2023[xla:6](20) Loss=0.01362 Rate=2343.52 GlobalRate=2057.67 Time=Thu Jun 15 16:22:54 2023
#
#
#
#
#
#
#
# [xla:7](40) Loss=0.05434 Rate=3385.51 GlobalRate=2708.13 Time=Thu Jun 15 16:22:54 2023[xla:2](40) Loss=0.03897 Rate=3334.19 GlobalRate=2700.25 Time=Thu Jun 15 16:22:54 2023[xla:3](40) Loss=0.06069 Rate=3430.06 GlobalRate=2726.16 Time=Thu Jun 15 16:22:54 2023[xla:4](40) Loss=0.02196 Rate=3441.40 GlobalRate=2700.67 Time=Thu Jun 15 16:22:54 2023[xla:0](40) Loss=0.10293 Rate=3424.35 GlobalRate=2701.73 Time=Thu Jun 15 16:22:54 2023[xla:1](40) Loss=0.05729 Rate=3302.43 GlobalRate=2705.45 Time=Thu Jun 15 16:22:54 2023[xla:6](40) Loss=0.05014 Rate=3413.88 GlobalRate=2724.01 Time=Thu Jun 15 16:22:54 2023[xla:5](40) Loss=0.02904 Rate=3480.36 GlobalRate=2728.19 Time=Thu Jun 15 16:22:54 2023
#
#
#
#
#
#
#
# Finished training epoch 4
# [xla:0] Accuracy=98.52%
# [xla:1] Accuracy=98.50%[xla:7] Accuracy=98.53%[xla:3] Accuracy=98.51%[xla:2] Accuracy=98.52%[xla:5] Accuracy=98.53%
#
#
#
#
# [xla:6] Accuracy=98.51%
# [xla:4] Accuracy=98.52%
# [xla:3](0) Loss=0.03676 Rate=256.50 GlobalRate=256.49 Time=Thu Jun 15 16:22:58 2023
# [xla:2](0) Loss=0.08464 Rate=215.51 GlobalRate=215.50 Time=Thu Jun 15 16:22:58 2023
# [xla:0](0) Loss=0.05580 Rate=244.18 GlobalRate=244.17 Time=Thu Jun 15 16:22:58 2023
# [xla:7](0) Loss=0.09322 Rate=195.15 GlobalRate=195.15 Time=Thu Jun 15 16:22:58 2023
# [xla:1](0) Loss=0.04604 Rate=190.48 GlobalRate=190.47 Time=Thu Jun 15 16:22:58 2023[xla:4](0) Loss=0.05399 Rate=191.79 GlobalRate=191.78 Time=Thu Jun 15 16:22:58 2023
# [xla:5](0) Loss=0.03359 Rate=216.11 GlobalRate=216.10 Time=Thu Jun 15 16:22:58 2023[xla:6](0) Loss=0.07981 Rate=195.34 GlobalRate=195.34 Time=Thu Jun 15 16:22:58 2023
#
#
# [xla:2](20) Loss=0.06765 Rate=2192.72 GlobalRate=2031.57 Time=Thu Jun 15 16:22:59 2023[xla:6](20) Loss=0.00956 Rate=2442.51 GlobalRate=2059.89 Time=Thu Jun 15 16:22:59 2023[xla:4](20) Loss=0.05753 Rate=2433.90 GlobalRate=2037.83 Time=Thu Jun 15 16:22:59 2023[xla:7](20) Loss=0.10019 Rate=2377.99 GlobalRate=2030.58 Time=Thu Jun 15 16:22:59 2023[xla:0](20) Loss=0.06799 Rate=2185.05 GlobalRate=2133.22 Time=Thu Jun 15 16:22:59 2023[xla:3](20) Loss=0.09605 Rate=1999.96 GlobalRate=2054.14 Time=Thu Jun 15 16:22:59 2023[xla:1](20) Loss=0.02513 Rate=2429.79 GlobalRate=2029.24 Time=Thu Jun 15 16:22:59 2023[xla:5](20) Loss=0.09298 Rate=2461.29 GlobalRate=2169.35 Time=Thu Jun 15 16:22:59 2023
#
#
#
#
#
#
#
# [xla:7](40) Loss=0.04352 Rate=3306.90 GlobalRate=2656.15 Time=Thu Jun 15 16:23:00 2023[xla:6](40) Loss=0.04085 Rate=3332.46 GlobalRate=2681.61 Time=Thu Jun 15 16:23:00 2023[xla:4](40) Loss=0.01724 Rate=3328.72 GlobalRate=2662.29 Time=Thu Jun 15 16:23:00 2023[xla:3](40) Loss=0.04683 Rate=3155.86 GlobalRate=2676.78 Time=Thu Jun 15 16:23:00 2023[xla:1](40) Loss=0.04685 Rate=3327.92 GlobalRate=2655.09 Time=Thu Jun 15 16:23:00 2023[xla:2](40) Loss=0.03735 Rate=3232.40 GlobalRate=2656.86 Time=Thu Jun 15 16:23:00 2023[xla:0](40) Loss=0.09691 Rate=3228.28 GlobalRate=2744.05 Time=Thu Jun 15 16:23:00 2023[xla:5](40) Loss=0.02148 Rate=3337.64 GlobalRate=2774.03 Time=Thu Jun 15 16:23:00 2023
#
#
#
#
#
#
#
# Finished training epoch 5
# [xla:5] Accuracy=98.70%
# [xla:2] Accuracy=98.67%
# [xla:0] Accuracy=98.70%[xla:1] Accuracy=98.70%[xla:3] Accuracy=98.68%[xla:7] Accuracy=98.71%
#
#
#
# [xla:4] Accuracy=98.68%
# [xla:6] Accuracy=98.72%
# [xla:1](0) Loss=0.03875 Rate=228.73 GlobalRate=228.72 Time=Thu Jun 15 16:23:04 2023
# [xla:3](0) Loss=0.02817 Rate=208.68 GlobalRate=208.68 Time=Thu Jun 15 16:23:04 2023
# [xla:2](0) Loss=0.07049 Rate=184.80 GlobalRate=184.79 Time=Thu Jun 15 16:23:04 2023
# [xla:5](0) Loss=0.02541 Rate=180.19 GlobalRate=180.19 Time=Thu Jun 15 16:23:04 2023
# [xla:0](0) Loss=0.04866 Rate=176.37 GlobalRate=176.36 Time=Thu Jun 15 16:23:04 2023
# [xla:7](0) Loss=0.08455 Rate=175.69 GlobalRate=175.68 Time=Thu Jun 15 16:23:04 2023[xla:4](0) Loss=0.04884 Rate=177.73 GlobalRate=177.72 Time=Thu Jun 15 16:23:04 2023
#
# [xla:6](0) Loss=0.06250 Rate=218.82 GlobalRate=218.82 Time=Thu Jun 15 16:23:04 2023
# [xla:2](20) Loss=0.05969 Rate=2205.30 GlobalRate=1901.91 Time=Thu Jun 15 16:23:04 2023[xla:7](20) Loss=0.09028 Rate=2321.05 GlobalRate=1905.02 Time=Thu Jun 15 16:23:04 2023[xla:6](20) Loss=0.00694 Rate=2451.41 GlobalRate=2176.97 Time=Thu Jun 15 16:23:04 2023[xla:0](20) Loss=0.06101 Rate=2312.30 GlobalRate=1905.11 Time=Thu Jun 15 16:23:04 2023[xla:3](20) Loss=0.08778 Rate=2007.53 GlobalRate=1904.09 Time=Thu Jun 15 16:23:04 2023[xla:1](20) Loss=0.01952 Rate=1925.01 GlobalRate=1923.62 Time=Thu Jun 15 16:23:04 2023[xla:5](20) Loss=0.08627 Rate=2251.92 GlobalRate=1899.65 Time=Thu Jun 15 16:23:04 2023[xla:4](20) Loss=0.05179 Rate=2347.04 GlobalRate=1926.74 Time=Thu Jun 15 16:23:04 2023
#
#
#
#
#
#
#
# [xla:2](40) Loss=0.03756 Rate=3282.32 GlobalRate=2555.93 Time=Thu Jun 15 16:23:05 2023[xla:1](40) Loss=0.03706 Rate=3171.64 GlobalRate=2576.43 Time=Thu Jun 15 16:23:05 2023[xla:0](40) Loss=0.09054 Rate=3326.60 GlobalRate=2559.37 Time=Thu Jun 15 16:23:05 2023[xla:5](40) Loss=0.01741 Rate=3301.86 GlobalRate=2554.13 Time=Thu Jun 15 16:23:05 2023[xla:6](40) Loss=0.03615 Rate=3381.56 GlobalRate=2799.71 Time=Thu Jun 15 16:23:05 2023[xla:7](40) Loss=0.03683 Rate=3328.15 GlobalRate=2558.65 Time=Thu Jun 15 16:23:05 2023[xla:3](40) Loss=0.04209 Rate=3203.03 GlobalRate=2557.89 Time=Thu Jun 15 16:23:05 2023
#
# [xla:4](40) Loss=0.01408 Rate=3338.01 GlobalRate=2578.46 Time=Thu Jun 15 16:23:05 2023
#
#
#
#
#
# Finished training epoch 6
# [xla:2] Accuracy=98.81%[xla:0] Accuracy=98.83%
#
# [xla:3] Accuracy=98.81%
# [xla:6] Accuracy=98.84%[xla:7] Accuracy=98.82%[xla:4] Accuracy=98.81%
#
#
# [xla:1] Accuracy=98.85%[xla:5] Accuracy=98.82%
#
# [xla:7](0) Loss=0.07834 Rate=251.21 GlobalRate=251.21 Time=Thu Jun 15 16:23:09 2023
# [xla:4](0) Loss=0.04700 Rate=210.56 GlobalRate=210.55 Time=Thu Jun 15 16:23:09 2023
# [xla:0](0) Loss=0.04262 Rate=185.66 GlobalRate=185.66 Time=Thu Jun 15 16:23:09 2023
# [xla:5](0) Loss=0.02082 Rate=220.13 GlobalRate=220.11 Time=Thu Jun 15 16:23:09 2023[xla:3](0) Loss=0.02205 Rate=183.13 GlobalRate=183.12 Time=Thu Jun 15 16:23:09 2023
#
# [xla:2](0) Loss=0.06291 Rate=185.10 GlobalRate=185.09 Time=Thu Jun 15 16:23:09 2023[xla:6](0) Loss=0.05179 Rate=185.69 GlobalRate=185.68 Time=Thu Jun 15 16:23:09 2023
#
# [xla:1](0) Loss=0.03211 Rate=225.33 GlobalRate=225.33 Time=Thu Jun 15 16:23:09 2023
# [xla:2](20) Loss=0.05264 Rate=2210.19 GlobalRate=1905.58 Time=Thu Jun 15 16:23:10 2023[xla:5](20) Loss=0.08129 Rate=2187.95 GlobalRate=2047.28 Time=Thu Jun 15 16:23:10 2023[xla:1](20) Loss=0.01694 Rate=2290.82 GlobalRate=2123.17 Time=Thu Jun 15 16:23:10 2023[xla:7](20) Loss=0.08118 Rate=1916.96 GlobalRate=1983.55 Time=Thu Jun 15 16:23:10 2023[xla:0](20) Loss=0.05587 Rate=2162.75 GlobalRate=1886.43 Time=Thu Jun 15 16:23:10 2023[xla:3](20) Loss=0.08129 Rate=2193.86 GlobalRate=1888.57 Time=Thu Jun 15 16:23:10 2023[xla:6](20) Loss=0.00532 Rate=2211.63 GlobalRate=1909.10 Time=Thu Jun 15 16:23:10 2023[xla:4](20) Loss=0.04491 Rate=2009.33 GlobalRate=1912.08 Time=Thu Jun 15 16:23:10 2023
#
#
#
#
#
#
#
# [xla:0](40) Loss=0.08436 Rate=3249.30 GlobalRate=2536.30 Time=Thu Jun 15 16:23:10 2023[xla:7](40) Loss=0.03116 Rate=3150.76 GlobalRate=2624.74 Time=Thu Jun 15 16:23:10 2023[xla:6](40) Loss=0.03223 Rate=3270.20 GlobalRate=2557.67 Time=Thu Jun 15 16:23:10 2023[xla:1](40) Loss=0.03016 Rate=3300.61 GlobalRate=2747.28 Time=Thu Jun 15 16:23:10 2023[xla:4](40) Loss=0.01240 Rate=3191.57 GlobalRate=2561.17 Time=Thu Jun 15 16:23:10 2023[xla:2](40) Loss=0.03953 Rate=3268.18 GlobalRate=2553.95 Time=Thu Jun 15 16:23:10 2023[xla:3](40) Loss=0.03582 Rate=3261.77 GlobalRate=2538.29 Time=Thu Jun 15 16:23:10 2023[xla:5](40) Loss=0.01449 Rate=3256.63 GlobalRate=2680.36 Time=Thu Jun 15 16:23:10 2023
#
#
#
#
#
#
#
# Finished training epoch 7
# [xla:5] Accuracy=98.85%[xla:1] Accuracy=98.87%
#
# [xla:3] Accuracy=98.84%[xla:2] Accuracy=98.84%[xla:7] Accuracy=98.84%[xla:0] Accuracy=98.86%[xla:4] Accuracy=98.84%
#
#
#
#
# [xla:6] Accuracy=98.85%
# [xla:2](0) Loss=0.05748 Rate=235.29 GlobalRate=235.28 Time=Thu Jun 15 16:23:14 2023
# [xla:1](0) Loss=0.02637 Rate=199.53 GlobalRate=199.52 Time=Thu Jun 15 16:23:14 2023
# [xla:5](0) Loss=0.01802 Rate=191.90 GlobalRate=191.89 Time=Thu Jun 15 16:23:14 2023
# [xla:4](0) Loss=0.04521 Rate=187.71 GlobalRate=187.70 Time=Thu Jun 15 16:23:14 2023[xla:7](0) Loss=0.07338 Rate=191.81 GlobalRate=191.80 Time=Thu Jun 15 16:23:14 2023
#
# [xla:0](0) Loss=0.03795 Rate=188.13 GlobalRate=188.12 Time=Thu Jun 15 16:23:14 2023[xla:3](0) Loss=0.01890 Rate=182.22 GlobalRate=182.21 Time=Thu Jun 15 16:23:14 2023
# [xla:6](0) Loss=0.04473 Rate=211.20 GlobalRate=211.19 Time=Thu Jun 15 16:23:14 2023
#
# [xla:5](20) Loss=0.07777 Rate=2265.74 GlobalRate=1963.87 Time=Thu Jun 15 16:23:15 2023[xla:2](20) Loss=0.04866 Rate=1992.38 GlobalRate=1986.42 Time=Thu Jun 15 16:23:15 2023[xla:7](20) Loss=0.07388 Rate=2322.16 GlobalRate=1989.04 Time=Thu Jun 15 16:23:15 2023[xla:3](20) Loss=0.07400 Rate=2382.56 GlobalRate=1965.63 Time=Thu Jun 15 16:23:15 2023[xla:6](20) Loss=0.00436 Rate=2396.05 GlobalRate=2115.61 Time=Thu Jun 15 16:23:15 2023[xla:4](20) Loss=0.03866 Rate=2314.97 GlobalRate=1965.38 Time=Thu Jun 15 16:23:15 2023
#
#
# [xla:0](20) Loss=0.04969 Rate=2381.08 GlobalRate=1996.22 Time=Thu Jun 15 16:23:15 2023
#
#
#
# [xla:1](20) Loss=0.01548 Rate=2192.03 GlobalRate=1963.87 Time=Thu Jun 15 16:23:15 2023
# [xla:6](40) Loss=0.02759 Rate=3319.08 GlobalRate=2731.59 Time=Thu Jun 15 16:23:16 2023[xla:2](40) Loss=0.04096 Rate=3157.26 GlobalRate=2618.83 Time=Thu Jun 15 16:23:16 2023[xla:5](40) Loss=0.01316 Rate=3266.37 GlobalRate=2598.60 Time=Thu Jun 15 16:23:16 2023[xla:0](40) Loss=0.07965 Rate=3313.38 GlobalRate=2627.77 Time=Thu Jun 15 16:23:16 2023[xla:1](40) Loss=0.02481 Rate=3236.77 GlobalRate=2598.55 Time=Thu Jun 15 16:23:16 2023[xla:3](40) Loss=0.03085 Rate=3312.73 GlobalRate=2600.04 Time=Thu Jun 15 16:23:16 2023[xla:7](40) Loss=0.02640 Rate=3288.17 GlobalRate=2620.80 Time=Thu Jun 15 16:23:16 2023[xla:4](40) Loss=0.01087 Rate=3288.03 GlobalRate=2600.65 Time=Thu Jun 15 16:23:16 2023
#
#
#
#
#
#
#
# Finished training epoch 8
# [xla:1] Accuracy=98.91%
# [xla:3] Accuracy=98.90%[xla:5] Accuracy=98.92%
#
# [xla:2] Accuracy=98.91%[xla:6] Accuracy=98.91%[xla:0] Accuracy=98.93%
# [xla:7] Accuracy=98.92%
#
#
# [xla:4] Accuracy=98.89%
# [xla:3](0) Loss=0.01703 Rate=238.78 GlobalRate=238.77 Time=Thu Jun 15 16:23:19 2023
# [xla:4](0) Loss=0.04301 Rate=218.47 GlobalRate=218.46 Time=Thu Jun 15 16:23:19 2023
# [xla:5](0) Loss=0.01567 Rate=209.29 GlobalRate=209.28 Time=Thu Jun 15 16:23:19 2023
# [xla:0](0) Loss=0.03275 Rate=198.38 GlobalRate=198.37 Time=Thu Jun 15 16:23:20 2023
# [xla:7](0) Loss=0.07052 Rate=188.18 GlobalRate=188.18 Time=Thu Jun 15 16:23:20 2023[xla:2](0) Loss=0.05424 Rate=190.81 GlobalRate=190.80 Time=Thu Jun 15 16:23:20 2023
#
# [xla:1](0) Loss=0.02287 Rate=186.75 GlobalRate=186.75 Time=Thu Jun 15 16:23:20 2023[xla:6](0) Loss=0.03873 Rate=190.89 GlobalRate=190.88 Time=Thu Jun 15 16:23:20 2023
#
# [xla:7](20) Loss=0.06870 Rate=2366.30 GlobalRate=1990.17 Time=Thu Jun 15 16:23:20 2023[xla:0](20) Loss=0.04407 Rate=2255.06 GlobalRate=1989.30 Time=Thu Jun 15 16:23:20 2023[xla:6](20) Loss=0.00356 Rate=2379.99 GlobalRate=2010.00 Time=Thu Jun 15 16:23:20 2023[xla:3](20) Loss=0.06839 Rate=1973.81 GlobalRate=1985.48 Time=Thu Jun 15 16:23:20 2023[xla:5](20) Loss=0.07114 Rate=2154.75 GlobalRate=1986.32 Time=Thu Jun 15 16:23:20 2023[xla:2](20) Loss=0.04388 Rate=2377.62 GlobalRate=2008.54 Time=Thu Jun 15 16:23:20 2023[xla:1](20) Loss=0.01352 Rate=2364.92 GlobalRate=1982.17 Time=Thu Jun 15 16:23:20 2023[xla:4](20) Loss=0.03375 Rate=2100.23 GlobalRate=1992.57 Time=Thu Jun 15 16:23:20 2023
#
#
#
#
#
#
#
# [xla:5](40) Loss=0.01149 Rate=3214.16 GlobalRate=2615.84 Time=Thu Jun 15 16:23:21 2023[xla:1](40) Loss=0.02150 Rate=3298.59 GlobalRate=2612.27 Time=Thu Jun 15 16:23:21 2023[xla:6](40) Loss=0.02377 Rate=3303.13 GlobalRate=2636.37 Time=Thu Jun 15 16:23:21 2023[xla:2](40) Loss=0.04155 Rate=3303.44 GlobalRate=2635.55 Time=Thu Jun 15 16:23:21 2023[xla:7](40) Loss=0.02270 Rate=3297.46 GlobalRate=2618.76 Time=Thu Jun 15 16:23:21 2023[xla:3](40) Loss=0.02919 Rate=3140.39 GlobalRate=2614.58 Time=Thu Jun 15 16:23:21 2023[xla:0](40) Loss=0.07748 Rate=3253.28 GlobalRate=2618.11 Time=Thu Jun 15 16:23:21 2023
# [xla:4](40) Loss=0.00910 Rate=3190.77 GlobalRate=2620.81 Time=Thu Jun 15 16:23:21 2023
#
#
#
#
#
#
# Finished training epoch 9
# [xla:1] Accuracy=98.96%
# [xla:0] Accuracy=98.95%[xla:4] Accuracy=98.95%[xla:3] Accuracy=98.95%[xla:2] Accuracy=98.95%[xla:5] Accuracy=98.95%
# [xla:6] Accuracy=98.95%
# [xla:7] Accuracy=98.96%
#
#
#
#
# [xla:2](0) Loss=0.05141 Rate=269.45 GlobalRate=269.44 Time=Thu Jun 15 16:23:25 2023
# [xla:5](0) Loss=0.01387 Rate=228.93 GlobalRate=228.92 Time=Thu Jun 15 16:23:25 2023[xla:7](0) Loss=0.06731 Rate=230.64 GlobalRate=230.64 Time=Thu Jun 15 16:23:25 2023
#
# [xla:6](0) Loss=0.03402 Rate=200.96 GlobalRate=200.96 Time=Thu Jun 15 16:23:25 2023
# [xla:3](0) Loss=0.01546 Rate=190.36 GlobalRate=190.35 Time=Thu Jun 15 16:23:25 2023
# [xla:0](0) Loss=0.02997 Rate=188.57 GlobalRate=188.56 Time=Thu Jun 15 16:23:25 2023
# [xla:1](0) Loss=0.02131 Rate=185.67 GlobalRate=185.66 Time=Thu Jun 15 16:23:25 2023[xla:4](0) Loss=0.04102 Rate=214.74 GlobalRate=214.74 Time=Thu Jun 15 16:23:25 2023
#
# [xla:1](20) Loss=0.01198 Rate=2392.44 GlobalRate=1988.16 Time=Thu Jun 15 16:23:26 2023[xla:7](20) Loss=0.06453 Rate=2075.18 GlobalRate=2021.67 Time=Thu Jun 15 16:23:26 2023[xla:2](20) Loss=0.03843 Rate=1864.74 GlobalRate=1992.16 Time=Thu Jun 15 16:23:26 2023[xla:3](20) Loss=0.06337 Rate=2347.82 GlobalRate=1993.22 Time=Thu Jun 15 16:23:26 2023[xla:0](20) Loss=0.04010 Rate=2363.67 GlobalRate=1991.02 Time=Thu Jun 15 16:23:26 2023[xla:6](20) Loss=0.00303 Rate=2288.89 GlobalRate=2017.34 Time=Thu Jun 15 16:23:26 2023[xla:4](20) Loss=0.03063 Rate=2383.17 GlobalRate=2125.43 Time=Thu Jun 15 16:23:26 2023
#
#
# [xla:5](20) Loss=0.06373 Rate=2069.86 GlobalRate=2012.62 Time=Thu Jun 15 16:23:26 2023
#
#
#
#
# [xla:0](40) Loss=0.07342 Rate=3345.36 GlobalRate=2637.07 Time=Thu Jun 15 16:23:26 2023[xla:1](40) Loss=0.01812 Rate=3355.15 GlobalRate=2633.89 Time=Thu Jun 15 16:23:26 2023[xla:2](40) Loss=0.04059 Rate=3144.39 GlobalRate=2637.60 Time=Thu Jun 15 16:23:26 2023[xla:5](40) Loss=0.01114 Rate=3231.66 GlobalRate=2657.77 Time=Thu Jun 15 16:23:26 2023[xla:3](40) Loss=0.02654 Rate=3338.13 GlobalRate=2638.73 Time=Thu Jun 15 16:23:26 2023[xla:4](40) Loss=0.00827 Rate=3352.28 GlobalRate=2754.92 Time=Thu Jun 15 16:23:26 2023[xla:7](40) Loss=0.02101 Rate=3226.79 GlobalRate=2663.32 Time=Thu Jun 15 16:23:26 2023[xla:6](40) Loss=0.02105 Rate=3312.59 GlobalRate=2659.59 Time=Thu Jun 15 16:23:26 2023
#
#
#
#
#
#
#
# Finished training epoch 10
# [xla:7] Accuracy=99.00%[xla:2] Accuracy=98.96%[xla:1] Accuracy=98.98%
#
# [xla:6] Accuracy=98.96%
#
# [xla:4] Accuracy=98.96%[xla:3] Accuracy=98.97%[xla:5] Accuracy=98.99%
#
# [xla:0] Accuracy=99.00%

# %% [markdown]
# ## Visualize Predictions

# %%
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread(RESULT_IMG_PATH, cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=1100x900 at 0x7F44488BB940>
